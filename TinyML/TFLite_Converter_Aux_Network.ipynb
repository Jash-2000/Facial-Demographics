# %%
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/Jash')
# Out:
# Mounted at /Jash

# %%
model = tf.keras.models.load_model('/Jash/My Drive/Amodel.h5')

# %%
tf.keras.utils.plot_model(model, to_file='/Jash/My Drive/model.png')

# %%
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# %%
print(len(tflite_model))
# Out:
# 19286992
